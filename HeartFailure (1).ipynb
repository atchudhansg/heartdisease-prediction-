# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
#  _cp: Refers to chest pain type. It's categorized into four types: 0: Typical angina 1: Atypical angina 2: Non-anginal pain 3: Asymptomatic
#
# _trestbps: Denotes the resting blood pressure (in mm Hg) of the patient upon admission to the hospital.
#
# _chol: Stands for serum cholesterol level (in mg/dl).
#
# _fbs: Represents the fasting blood sugar level (> 120 mg/dl is considered as 1 and <= 120 mg/dl is considered as 0).
#
# _restecg: Refers to resting electrocardiographic results. It categorizes into three types: 0: Normal 1: Having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV) 2: Showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# _thalach: Represents the maximum heart rate achieved.
#
# _exang: Indicates exercise-induced angina (1 = yes, 0 = no).
#
# _oldpeak: Refers to the ST depression induced by exercise relative to rest.
#
# _slope: Denotes the slope of the peak exercise ST segment. It's categorized into three types: 0: Upsloping 1: Flat 2: Downsloping
#
# _ca: Represents the number of major vessels (0-3) colored by fluoroscopy.
#
# _thal: Refers to a blood disorder called thalassemia. It's categorized into three types: 1: Normal 2: Fixed defect 3: Reversible defect
#
# _target: Indicates whether the patient has heart failure or not (1 = presence, 0 = absence).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
#checking for null
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
#checking for duplicate values and removing them
df.duplicated().sum()
# Out:
# 723

# %%
df=df.drop_duplicates()
print(df.shape)
df.reset_index(inplace=True)
df
# Out:
# (302, 14)
#      index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0        0   52    1   0       125   212    0        1      168      0
# 1        1   53    1   0       140   203    1        0      155      1
# 2        2   70    1   0       145   174    0        1      125      1
# 3        3   61    1   0       148   203    0        1      161      0
# 4        4   62    0   0       138   294    1        1      106      0
# ..     ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 297    723   68    0   2       120   211    0        0      115      0
# 298    733   44    0   2       108   141    0        1      175      0
# 299    739   52    1   0       128   255    0        1      161      1
# 300    843   59    1   3       160   273    0        0      125      0
# 301    878   54    1   0       120   188    0        1      113      0
#
#      oldpeak  slope  ca  thal  target
# 0        1.0      2   2     3       0
# ...

# %%
#existence of outliers since it is beyond the fringes
import seaborn as sns

sns.boxplot(x='trestbps',data=df)
# Out:
# <Axes: xlabel='trestbps'>

# %%
sns.boxplot(x='chol',data=df)
# Out:
# <Axes: xlabel='chol'>

# %%
sns.boxplot(x='thalach',data=df) #existence of outlier
# Out:
# <Axes: xlabel='thalach'>

# %%
sns.boxplot(x='oldpeak',data=df)
# Out:
# <Axes: xlabel='oldpeak'>

# %%
sns.boxplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
df.shape
# Out:
# (302, 15)

# %%
c_num = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
c_cat = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
df2 = df
for c in c_num:
    print('-'*10, c, '-'*10)

    Q1 = np.percentile(df2[c], 25)
    Q3 = np.percentile(df2[c], 75)
    print(f'1st: {Q1}, 3st: {Q3}')

    IQR = Q3 - Q1
    print(f'IQR = {IQR}')

    lim_inf = Q1 - 1.5 * IQR
    lim_sup = Q3 + 1.5 * IQR
    print(f'Low: {lim_inf}, Upp {lim_sup}')

    outliers = (df2[c] < lim_inf) | (df2[c] > lim_sup)
    print("Outliers:", outliers.sum())

    print("Outliers values:")
    print(df2[c][outliers])

    df3 = df2[(df2[c] <= lim_sup)]
    df3 = df3[(df3[c] >= lim_inf)]
    print(df2.shape, df3.shape)
    df2 = df3
# Out:
# ---------- age ----------
# 1st: 48.0, 3st: 61.0
# IQR = 13.0
# Low: 28.5, Upp 80.5
# Outliers: 0
# Outliers values:
# Series([], Name: age, dtype: int64)
# (302, 15) (302, 15)
# ---------- trestbps ----------
# 1st: 120.0, 3st: 140.0
# IQR = 20.0
# Low: 90.0, Upp 170.0
# Outliers: 9
# Outliers values:
# 28     180
# 44     178
# 76     174
# 112    180
# 124    192
# 142    200
# 226    172
# 248    180
# 271    178
# Name: trestbps, dtype: int64
# (302, 15) (293, 15)
# ---------- chol ----------
# 1st: 211.0, 3st: 274.0
# IQR = 63.0
# Low: 116.5, Upp 368.5
# Outliers: 5
# Outliers values:
# 104    417
# 128    564
# 144    409
# 183    394
# 260    407
# Name: chol, dtype: int64
# (293, 15) (288, 15)
# ---------- thalach ----------
# 1st: 132.0, 3st: 167.25
# IQR = 35.25
# Low: 79.125, Upp 220.125
# Outliers: 1
# Outliers values:
# 188    71
# Name: thalach, dtype: int64
# (288, 15) (287, 15)
# ---------- oldpeak ----------
# 1st: 0.0, 3st: 1.6
# IQR = 1.6
# ...

# %%
df=df2


df.reset_index(inplace=True)
df
# Out:
#      level_0  index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  \
# 0          0      0   52    1   0       125   212    0        1      168
# 1          1      1   53    1   0       140   203    1        0      155
# 2          2      2   70    1   0       145   174    0        1      125
# 3          3      3   61    1   0       148   203    0        1      161
# 4          4      4   62    0   0       138   294    1        1      106
# ..       ...    ...  ...  ...  ..       ...   ...  ...      ...      ...
# 278      297    723   68    0   2       120   211    0        0      115
# 279      298    733   44    0   2       108   141    0        1      175
# 280      299    739   52    1   0       128   255    0        1      161
# 281      300    843   59    1   3       160   273    0        0      125
# 282      301    878   54    1   0       120   188    0        1      113
#
#      exang  oldpeak  slope  ca  thal  target
# 0        0      1.0      2   2     3       0
# ...

# %%
df=df.drop('level_0',axis=1)
df=df.drop('index',axis=1)

# %%
sns.boxplot(x='trestbps',data=df)
# Out:
# <Axes: xlabel='trestbps'>

# %%
sns.boxplot(x='chol',data=df)
# Out:
# <Axes: xlabel='chol'>

# %%
sns.boxplot(x='thalach',data=df)
# Out:
# <Axes: xlabel='thalach'>

# %%
sns.boxplot(x='oldpeak',data=df)
# Out:
# <Axes: xlabel='oldpeak'>

# %% [markdown]
# Preparing Data for Model

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 278   68    0   2       120   211    0        0      115      0      1.5
# 279   44    0   2       108   141    0        1      175      0      0.6
# 280   52    1   0       128   255    0        1      161      1      0.0
# 281   59    1   3       160   273    0        0      125      0      0.0
# 282   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
from google.colab import files

df.to_csv('result.csv', index=False)


files.download('result.csv')

# %%
df["target"].value_counts() #not a uniform distribution of target variables
# Out:
# target
# 1    158
# 0    125
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
df[c_num]=scalar.fit_transform(df[c_num])
df
# Out:
#           age  trestbps      chol   thalach   oldpeak  target  sex_1   cp_1  \
# 0   -0.224919 -0.317917 -0.680075  0.796365  0.046903       0   True  False
# 1   -0.115174  0.658608 -0.881981  0.222452  2.096513       0   True  False
# 2    1.750489  0.984117 -1.532566 -1.101964  1.608511       0   True  False
# 3    0.762785  1.179422 -0.881981  0.487335 -0.929101       0   True  False
# 4    0.872530  0.528405  1.159512 -1.940760  0.925307       0  False  False
# ..        ...       ...       ...       ...       ...     ...    ...    ...
# 278  1.530999 -0.643426 -0.702509 -1.543436  0.534906       1  False  False
# 279 -1.102878 -1.424646 -2.272888  1.105396 -0.343498       1  False  False
# 280 -0.224919 -0.122612  0.284587  0.487335 -0.929101       0   True  False
# 281  0.543295  1.960642  0.688398 -1.101964 -0.929101       0   True  False
# 282 -0.005429 -0.643426 -1.218491 -1.631730  0.437305       0   True  False
#
# ...

# %%
from sklearn.model_selection import train_test_split

x=df.drop('target',axis=1)
y=df['target']

print(x.shape,y.shape)
# Out:
# (283, 13) (283,)

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 278   68    0   2       120   211    0        0      115      0      1.5
# 279   44    0   2       108   141    0        1      175      0      0.6
# 280   52    1   0       128   255    0        1      161      1      0.0
# 281   59    1   3       160   273    0        0      125      0      0.0
# 282   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal
# 0        2   2     3
# 1        0   0     3
# 2        0   0     3
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 278    1
# 279    1
# 280    0
# 281    0
# 282    0
# Name: target, Length: 283, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (226, 22) (226, 1)
# (57, 22) (57, 1)

# %% [markdown]
# Testing with models

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()

model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
accc=[]
from sklearn.metrics import accuracy_score

y_predict=model.predict(x_test)
acc=accuracy_score(y_test,y_predict)*100
accc.append(acc)

print(accuracy_score(y_test,y_predict)*100)
# Out:
# 82.45614035087719

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_predict)
# Out:
# array([[20,  6],
#        [ 4, 27]])

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model1=RandomForestClassifier()
model1.fit(x_train,y_train)
y_predict1=model1.predict(x_test)

print(accuracy_score(y_test,y_predict1)*100)
acc1=accuracy_score(y_test,y_predict1)*100
accc.append(acc1)
# Out:
# 80.7017543859649
# <ipython-input-191-51832562c94f>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model1.fit(x_train,y_train)

# %%
confusion_matrix(y_test,y_predict1)
# Out:
# array([[20,  6],
#        [ 5, 26]])

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model2=KNeighborsClassifier()
model2.fit(x_train,y_train)
y_predict2=model2.predict(x_test)
print(accuracy_score(y_test,y_predict2)*100)
acc2=accuracy_score(y_test,y_predict2)*100
accc.append(acc2)
# Out:
# 78.94736842105263
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
confusion_matrix(y_test,y_predict2)
# Out:
# array([[21,  5],
#        [ 7, 24]])

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model3=DecisionTreeClassifier()
model3.fit(x_train,y_train)
y_predict3=model3.predict(x_test)
print(accuracy_score(y_test,y_predict3)*100)

acc3=accuracy_score(y_test,y_predict3)*100
accc.append(acc3)
# Out:
# 70.17543859649122

# %%
confusion_matrix(y_test,y_predict3)
# Out:
# array([[20,  6],
#        [11, 20]])

# %% [markdown]
# ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier

model4=AdaBoostClassifier()
model4.fit(x_train,y_train)
y_predict4=model4.predict(x_test)
print(accuracy_score(y_test,y_predict4)*100)
acc4=accuracy_score(y_test,y_predict4)*100
accc.append(acc4)
# Out:
# 78.94736842105263
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
confusion_matrix(y_test,y_predict4)
# Out:
# array([[19,  7],
#        [ 5, 26]])

# %%
from sklearn.naive_bayes import GaussianNB
model5=GaussianNB()
model5.fit(x_train,y_train)
y_predict5=model5.predict(x_test)
print(accuracy_score(y_test,y_predict5)*100)

acc5=accuracy_score(y_test,y_predict5)*100
accc.append(acc5)
# Out:
# 87.71929824561403
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
confusion_matrix(y_test,y_predict5)
# Out:
# array([[23,  3],
#        [ 4, 27]])

# %% [markdown]
# Results

# %%
models=['LOGISTIC REGRESSION','RANDOM FOREST','KNN','DECISION TREE','ADABOOST','NAIVE BAYES']
result=pd.DataFrame(models,columns=['models'])
result["accuracy"]=accc
result
# Out:
#                 models   accuracy
# 0  LOGISTIC REGRESSION  82.456140
# 1        RANDOM FOREST  80.701754
# 2                  KNN  78.947368
# 3        DECISION TREE  70.175439
# 4             ADABOOST  78.947368
# 5          NAIVE BAYES  87.719298

# %% [markdown]
# best parameters for random forest

# %%
from sklearn.model_selection import GridSearchCV
def find_best_params_rf(X_train, y_train):

    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 5, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }


    rf = RandomForestClassifier(random_state=42)


    grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                               scoring='accuracy', cv=5, verbose=0, n_jobs=-1)


    grid_search.fit(X_train, y_train)

    return grid_search.best_params_

# %%
best_para = find_best_params_rf(x_train, y_train)
best_para
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# {'max_depth': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'n_estimators': 100}

# %%
rf=RandomForestClassifier(max_depth= 5, min_samples_leaf = 4, min_samples_split = 10,n_estimators = 100)

# %% [markdown]
# combined model

# %%
from sklearn.ensemble import VotingClassifier

lr=LogisticRegression()
nb=GaussianNB()

ensemble_model = VotingClassifier(estimators=[('lr', lr), ('nb', nb)], voting='soft')

ensemble_model.fit(x_train,y_train)

y_pred=ensemble_model.predict(x_test)

print(accuracy_score(y_test,y_pred)*100)
# Out:
# 85.96491228070175
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
lr=LogisticRegression()


ensemble_model1 = VotingClassifier(estimators=[('lr', lr), ('rf', rf)], voting='soft')

ensemble_model1.fit(x_train,y_train)

y_pred1=ensemble_model1.predict(x_test)

print(accuracy_score(y_test,y_pred1)*100)
# Out:
# 82.45614035087719
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
nb=GaussianNB()


ensemble_model2 = VotingClassifier(estimators=[('nb', nb), ('rf', rf)], voting='soft')

ensemble_model2.fit(x_train,y_train)

y_pred2=ensemble_model2.predict(x_test)

print(accuracy_score(y_test,y_pred2)*100)
# Out:
# 85.96491228070175
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
